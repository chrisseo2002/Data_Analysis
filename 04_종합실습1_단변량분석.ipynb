# %% [markdown]
# # 종합실습1 단변량 분석

# %% [markdown]
# # 1.비즈니스 시나리오

# %% [markdown]
# ![](https://cdn.images.express.co.uk/img/dynamic/24/590x/child-car-seat-986556.jpg?r=1532946857754)

# %% [markdown]
# * 고객사는 카시트를 판매하는 회사 입니다.
#     * 최근 매출 하락에 대해 각 부서가 파악한 원인 다음과 같습니다.
#         * 최근에 경쟁사와의 가격 경쟁력이 하락하고 있고, 광고비용이 적절하게 집행되지 않음
#         * 너무 국내 시장에 집중됨.
#         * 지역마다의 구매력을 제대로 파악하지 못하고 있음.
#     * 그러나 이러한 분석은 데이터에 근거하고 있는지 의문이 듭니다.
#
# * 이 문제를 해결하고자 프로젝트 팀이 빌딩되었습니다.
#     * 여러분은 이 프로젝트팀에 DX 컨설턴트로써 데이터분석을 맡았습니다.
#     * 드디어 AIVLE 과정에서 갈고 닦은 실력을 발휘할 기회가 주어졌습니다.
#     * 자, 이제 단변량 분석을 통해 비즈니스 인사이트를 도출해 봅시다!
# ----
# * 반복되는 코드는 함수로 만듭시다!
#     * 함수를 만드는 순서
#         * 먼저 절차대로 코드를 작성해서 실행한다.
#         * 실행된 코드(오류가 없는 코드)를 가져다 함수로 구성한다.
#             * 입력과 출력 결정

# %% [markdown]
# # 2.환경준비

# %% [markdown]
# ## (1) 라이브러리 불러오기

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## (2) 데이터 로딩 : 카시트 판매량 데이터

# %% [markdown]
# |	변수명	|	설명	|	구분	|
# |----|----|----|
# |	Sales 	|	 각 지역 판매량(단위 : 1000개)	|	Target	|
# |	CompPrice 	|	 경쟁사 가격(단위 : 달러)	|	feature	|
# |	Income 	|	 지역 평균 소득(단위 : 1000달러)	|	feature	|
# |	Advertising 	|	 각 지역, 회사의 광고 예산(단위 : 1000달러)	|	feature	|
# |	Population 	|	 지역 인구수(단위 : 1000명)	|	feature	|
# |	Price 	|	 자사 지역별 판매가격	|	feature	|
# |	ShelveLoc 	|	 진열상태	|	feature	|
# |	Age 	|	 지역 인구의 평균 연령	|	feature	|
# |	Urban 	|	 도심 지역 여부(Yes,No)	|	feature	|
# |	US 	|	 매장이 미국에 있는지 여부(Yes,No)	|	feature	|

# %%
path = 'https://raw.githubusercontent.com/DA4BAM/dataset/master/Carseats2.csv'
data = pd.read_csv(path)
data.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %% [markdown]
# # 3.단변량분석 : 숫자형 변수

# %%
def eda_1_n(data, var, bins = 30) :
    display(data[[var]].describe().T)
    print()

    plt.figure(figsize = (8,6))
    plt.subplot(2,1,1)
    sns.histplot(x=data[var], bins = bins, kde = True)

    plt.subplot(2,1,2)
    sns.boxplot(x=data[var])

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## (1) Sales (Target)

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 각 지역 판매량 (단위: 1000개)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'Sales')
# Out:
#        count      mean       std  min   25%   50%   75%    max
# Sales  400.0  7.496325  2.824115  0.0  5.39  7.49  9.32  16.27

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 판매량이 0인 지점의 이유? 8
# 판매량이 높은 지점은 어떤 이유가 있을까?

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 고객별 평균 구매액

# %% [markdown]
# ## (2) CompPrice

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 경쟁사 가격 (단위: 달러)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'CompPrice')
# Out:
#            count     mean        std   min    25%    50%    75%    max
# CompPrice  400.0  124.975  15.334512  77.0  115.0  125.0  135.0  175.0

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 경쟁사는 주로 115달러 ~ 135달러의 가격대를 형성
# 대체로 비슷한 가격대의 상품을 출시 중

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 자사와 경쟁사의 가격 경쟁력

# %% [markdown]
# ## (3) Income

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 지역 평균 소득 (단위: 1000달러)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'Income')
# Out:
#         count     mean        std   min    25%   50%   75%    max
# Income  400.0  68.6575  27.986037  21.0  42.75  69.0  91.0  120.0

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 고른 분포를 보임 -> 보급형 부터 고급형까지 다양한 모델 필요

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 소득 구간별 구매액

# %% [markdown]
# ## (4) Advertising

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 각 지역, 회사의 광고 예산(단위 : 1000달러)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'Advertising')
# Out:
#              count   mean       std  min  25%  50%   75%   max
# Advertising  400.0  6.635  6.650364  0.0  0.0  5.0  12.0  29.0

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 광고에는 크게 신경쓰지 않는 경향을 보임

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 지점별 광고 예산과 매출의 상관관계

# %% [markdown]
# ## (5) Population

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 지역 인구수(단위 : 1000명)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'Population')
# Out:
#             count    mean         std   min    25%    50%    75%    max
# Population  400.0  264.84  147.376436  10.0  139.0  272.0  398.5  509.0

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 대체로 고른 인구 분포를 가짐

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 지역별 연령 분포 조사 필요

# %% [markdown]
# ## (6) Price

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 자사 지역별 판매가격

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'Price')
# Out:
#        count     mean        std   min    25%    50%    75%    max
# Price  400.0  115.795  23.676664  24.0  100.0  117.0  131.0  191.0

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 경쟁사와의 가격 비교

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
sns.kdeplot(x = data['Price'], label = 'Price')
sns.kdeplot(x = data['CompPrice'], label = 'CompPrice')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## (7) Age

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 지역 인구의 평균 연령

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_n(data, 'Age')
# Out:
#      count     mean        std   min    25%   50%   75%   max
# Age  400.0  53.3225  16.200297  25.0  39.75  54.5  66.0  80.0

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 매장이 있는 지역들의 평균 연령대가 너무 높음
# 젊은 부부들이 많이 거주하는 지역을 타겟팅 할 필요가 있음

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %% [markdown]
# # 4.단변량분석 : 범주형 변수

# %%
# 범주형 변수에 대한 단변량 분석 함수
def eda_1_c(data, var) :
    # 기초 통계량
    print(f' <<<  {var}   >>')
    cnt = data[var].value_counts()
    prop = data[var].value_counts()/data.shape[0]
    temp = pd.DataFrame({'Class':cnt.index, 'Count':cnt.values, 'Prop':prop.values})
    display(temp)
    # 시각화
    sns.countplot(x = var, data = data)
    plt.grid()
    plt.show()

# %% [markdown]
# ## (1) Urban

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 도심 지역 여부(Yes,No)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_c(data, 'Urban')
# Out:
#  <<<  Urban   >>
#   Class  Count   Prop
# 0   Yes    282  0.705
# 1    No    118  0.295

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 도시에 사는 사람이 월등히 많음

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 도심, 비도심의 매출 차이

# %% [markdown]
# ## (2) ShelveLoc

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 진열상태

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_c(data, 'ShelveLoc')
# Out:
#  <<<  ShelveLoc   >>
#     Class  Count    Prop
# 0  Medium    219  0.5475
# 1     Bad     96  0.2400
# 2    Good     85  0.2125

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 나쁜 진열 상태의 제품이 너무 많음

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 진열 상태별 판매량

# %% [markdown]
# ## (3) US

# %% [markdown]
# 1) 변수의 비즈니스 의미

# %%
# 매장이 미국에 있는지 여부(Yes,No)

# %% [markdown]
# 2) 기초통계량(수치화)

# %%
eda_1_c(data, 'US')
# Out:
#  <<<  US   >>
#   Class  Count   Prop
# 0   Yes    258  0.645
# 1    No    142  0.355

# %% [markdown]
# 3) 분포 확인(시각화)

# %% [markdown]
# 4) 기초통계량과 분포를 통해서 파악한 내용을 적어 봅시다.
#
# 보이는 그대로를 넘어, 비즈니스 관점에서 고민하며 적어 봅시다.

# %%
# 생각보다 해외 시장에 많이 진출 해 있음

# %% [markdown]
# 5) 추가 분석해 볼 사항이 있나요?

# %%
# 미국 내의 매장과 해외 매장의 매출 차이
